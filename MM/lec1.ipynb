# %%
import sys
a=[]
print(sys.getrefcount(a))
# Out:
# 2

# %%
b=a
print(sys.getrefcount(b))
# Out:
# 3

# %%
del b
print(sys.getrefcount(a))
# Out:
# 2

# %%
import gc

gc.enable()

# %%
gc.disable()

# %%
gc.collect()
# Out:
# 22

# %%
print(gc.get_stats())
# Out:
# [{'collections': 178, 'collected': 1377, 'uncollectable': 0}, {'collections': 16, 'collected': 126, 'uncollectable': 0}, {'collections': 2, 'collected': 96, 'uncollectable': 0}]

# %%
print(gc.garbage)
# Out:
# []

# %%
import gc
class Myobject:
    def __init__(self, name):
        self.name=name
        print(f"object {self.name} created")
    def __del__(self):
        print(f"Object {self.name} deleted")
ob1=Myobject("obj1")
ob2=Myobject("obj2")
ob1.ref=ob2
ob2.ref=ob1

del ob1
del ob2

gc.collect()
# Out:
# object obj1 created
# object obj2 created
# Object obj1 deleted
# Object obj2 deleted
# 1106

# %%
def gen(n):
    for i in range(n):
        yield i

for n in gen(1000000):
    print(n)
    if n>10:
        break
# Out:
# <generator object gen at 0x00000225DC821CB0>

# %%
import tracemalloc
def create_list():
    return [i for i in range(10000)]
def main():
    tracemalloc.start()
    create_list()
    snapshot=tracemalloc.take_snapshot()
    top_stats=snapshot.statistics("lineno")

    print('[ Top 10]')
    for stat in top_stats:
        print(stat)
main()
# Out:
# [ Top 10]
# c:\Users\kriti\anaconda3\Lib\site-packages\tornado\platform\asyncio.py:574: size=144 KiB, count=5, average=28.8 KiB
# <frozen genericpath>:89: size=50.7 KiB, count=523, average=99 B
# c:\Users\kriti\anaconda3\Lib\site-packages\pygments\style.py:94: size=17.8 KiB, count=281, average=65 B
# c:\Users\kriti\anaconda3\Lib\site-packages\pygments\lexer.py:488: size=17.2 KiB, count=220, average=80 B
# c:\Users\kriti\anaconda3\Lib\site-packages\IPython\core\compilerop.py:86: size=16.1 KiB, count=187, average=88 B
# c:\Users\kriti\anaconda3\Lib\ast.py:52: size=15.2 KiB, count=176, average=89 B
# c:\Users\kriti\anaconda3\Lib\site-packages\pygments\formatters\terminal256.py:44: size=14.4 KiB, count=290, average=51 B
# c:\Users\kriti\anaconda3\Lib\tokenize.py:576: size=14.2 KiB, count=261, average=56 B
# <string>:1: size=11.0 KiB, count=90, average=125 B
# c:\Users\kriti\anaconda3\Lib\site-packages\pygments\token.py:44: size=10.6 KiB, count=157, average=69 B
# c:\Users\kriti\anaconda3\Lib\site-packages\pygments\lexer.py:572: size=10.4 KiB, count=181, average=59 B
# c:\Users\kriti\anaconda3\Lib\site-packages\pygments\regexopt.py:77: size=8736 B, count=156, average=56 B
# c:\Users\kriti\anaconda3\Lib\asyncio\windows_events.py:487: size=8258 B, count=2, average=4129 B
# c:\Users\kriti\anaconda3\Lib\site-packages\pygments\lexer.py:537: size=6736 B, count=68, average=99 B
# <frozen genericpath>:92: size=6720 B, count=120, average=56 B
# c:\Users\kriti\anaconda3\Lib\site-packages\stack_data\core.py:430: size=4699 B, count=79, average=59 B
# c:\Users\kriti\anaconda3\Lib\site-packages\stack_data\core.py:427: size=4624 B, count=1, average=4624 B
# c:\Users\kriti\anaconda3\Lib\site-packages\pygments\style.py:95: size=4624 B, count=1, average=4624 B
# c:\Users\kriti\anaconda3\Lib\codeop.py:126: size=4554 B, count=66, average=69 B
# c:\Users\kriti\anaconda3\Lib\site-packages\pygments\lexer.py:543: size=4544 B, count=26, average=175 B
# c:\Users\kriti\anaconda3\Lib\site-packages\pygments\lexer.py:46: size=4544 B, count=17, average=267 B
# c:\Users\kriti\anaconda3\Lib\site-packages\pygments\style.py:112: size=4029 B, count=79, average=51 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:545: size=3274 B, count=28, average=117 B
# c:\Users\kriti\anaconda3\Lib\site-packages\pygments\formatters\terminal256.py:242: size=3264 B, count=1, average=3264 B
# c:\Users\kriti\anaconda3\Lib\site-packages\asttokens\line_numbers.py:44: size=3232 B, count=23, average=141 B
# c:\Users\kriti\anaconda3\Lib\site-packages\pygments\style.py:70: size=3196 B, count=68, average=47 B
# c:\Users\kriti\anaconda3\Lib\site-packages\pygments\lexer.py:517: size=3072 B, count=32, average=96 B
# c:\Users\kriti\anaconda3\Lib\site-packages\stack_data\utils.py:165: size=2409 B, count=24, average=100 B
# c:\Users\kriti\anaconda3\Lib\site-packages\pygments\style.py:61: size=2256 B, count=7, average=322 B
# c:\Users\kriti\anaconda3\Lib\site-packages\stack_data\core.py:712: size=2192 B, count=16, average=137 B
# c:\Users\kriti\anaconda3\Lib\site-packages\pygments\formatters\terminal256.py:180: size=2144 B, count=1, average=2144 B
# c:\Users\kriti\anaconda3\Lib\json\decoder.py:353: size=1832 B, count=24, average=76 B
# c:\Users\kriti\anaconda3\Lib\site-packages\pygments\lexer.py:514: size=1792 B, count=32, average=56 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:241: size=1720 B, count=25, average=69 B
# c:\Users\kriti\anaconda3\Lib\site-packages\pygments\lexer.py:544: size=1544 B, count=30, average=51 B
# c:\Users\kriti\anaconda3\Lib\site-packages\jupyter_client\session.py:100: size=1538 B, count=8, average=192 B
# c:\Users\kriti\anaconda3\Lib\site-packages\pygments\lexer.py:520: size=1536 B, count=32, average=48 B
# c:\Users\kriti\anaconda3\Lib\site-packages\pygments\lexer.py:553: size=1536 B, count=22, average=70 B
# c:\Users\kriti\anaconda3\Lib\site-packages\pygments\lexer.py:512: size=1516 B, count=32, average=47 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:234: size=1456 B, count=7, average=208 B
# c:\Users\kriti\anaconda3\Lib\dis.py:190: size=1214 B, count=6, average=202 B
# c:\Users\kriti\anaconda3\Lib\site-packages\pygments\lexer.py:503: size=1200 B, count=25, average=48 B
# c:\Users\kriti\anaconda3\Lib\site-packages\zmq\sugar\socket.py:808: size=1056 B, count=6, average=176 B
# c:\Users\kriti\anaconda3\Lib\site-packages\asttokens\line_numbers.py:60: size=992 B, count=31, average=32 B
# c:\Users\kriti\anaconda3\Lib\site-packages\zmq\sugar\attrsettr.py:44: size=987 B, count=21, average=47 B
# c:\Users\kriti\anaconda3\Lib\site-packages\jupyter_client\session.py:1057: size=972 B, count=5, average=194 B
# c:\Users\kriti\anaconda3\Lib\site-packages\IPython\core\compilerop.py:174: size=967 B, count=14, average=69 B
# c:\Users\kriti\anaconda3\Lib\site-packages\asttokens\util.py:268: size=960 B, count=15, average=64 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:209: size=954 B, count=14, average=68 B
# c:\Users\kriti\anaconda3\Lib\ast.py:405: size=941 B, count=18, average=52 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:799: size=936 B, count=9, average=104 B
# c:\Users\kriti\anaconda3\Lib\site-packages\traitlets\traitlets.py:731: size=927 B, count=15, average=62 B
# c:\Users\kriti\anaconda3\Lib\site-packages\ipykernel\iostream.py:345: size=824 B, count=13, average=63 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:783: size=800 B, count=20, average=40 B
# c:\Users\kriti\anaconda3\Lib\site-packages\asttokens\asttokens.py:62: size=792 B, count=2, average=396 B
# c:\Users\kriti\anaconda3\Lib\site-packages\asttokens\asttokens.py:59: size=792 B, count=2, average=396 B
# c:\Users\kriti\anaconda3\Lib\site-packages\ipykernel\iostream.py:275: size=784 B, count=9, average=87 B
# c:\Users\kriti\anaconda3\Lib\site-packages\pygments\formatters\terminal256.py:221: size=768 B, count=1, average=768 B
# c:\Users\kriti\anaconda3\Lib\threading.py:293: size=760 B, count=2, average=380 B
# c:\Users\kriti\anaconda3\Lib\site-packages\asttokens\util.py:267: size=754 B, count=14, average=54 B
# c:\Users\kriti\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3334: size=752 B, count=2, average=376 B
# c:\Users\kriti\anaconda3\Lib\site-packages\traitlets\traitlets.py:1543: size=744 B, count=12, average=62 B
# c:\Users\kriti\anaconda3\Lib\site-packages\IPython\core\ultratb.py:990: size=740 B, count=2, average=370 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:809: size=712 B, count=5, average=142 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:791: size=712 B, count=5, average=142 B
# c:\Users\kriti\anaconda3\Lib\site-packages\ipykernel\iostream.py:286: size=672 B, count=9, average=75 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:144: size=672 B, count=4, average=168 B
# c:\Users\kriti\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3380: size=666 B, count=2, average=333 B
# c:\Users\kriti\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3517: size=648 B, count=2, average=324 B
# c:\Users\kriti\anaconda3\Lib\asyncio\windows_events.py:743: size=616 B, count=6, average=103 B
# c:\Users\kriti\anaconda3\Lib\site-packages\asttokens\mark_tokens.py:98: size=608 B, count=2, average=304 B
# c:\Users\kriti\anaconda3\Lib\site-packages\traitlets\traitlets.py:1514: size=600 B, count=5, average=120 B
# c:\Users\kriti\anaconda3\Lib\asyncio\base_events.py:815: size=592 B, count=6, average=99 B
# c:\Users\kriti\anaconda3\Lib\site-packages\stack_data\core.py:128: size=576 B, count=12, average=48 B
# c:\Users\kriti\anaconda3\Lib\site-packages\stack_data\core.py:555: size=568 B, count=4, average=142 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:372: size=568 B, count=4, average=142 B
# c:\Users\kriti\anaconda3\Lib\site-packages\asttokens\util.py:269: size=568 B, count=1, average=568 B
# c:\Users\kriti\anaconda3\Lib\site-packages\asttokens\line_numbers.py:46: size=568 B, count=1, average=568 B
# c:\Users\kriti\anaconda3\Lib\site-packages\ipykernel\zmqshell.py:549: size=560 B, count=6, average=93 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:346: size=552 B, count=4, average=138 B
# c:\Users\kriti\anaconda3\Lib\site-packages\pygments\lexer.py:635: size=544 B, count=4, average=136 B
# c:\Users\kriti\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3104: size=520 B, count=4, average=130 B
# c:\Users\kriti\anaconda3\Lib\ast.py:207: size=488 B, count=5, average=98 B
# c:\Users\kriti\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3577: size=488 B, count=3, average=163 B
# c:\Users\kriti\anaconda3\Lib\site-packages\stack_data\core.py:520: size=480 B, count=12, average=40 B
# c:\Users\kriti\anaconda3\Lib\site-packages\ipykernel\ipkernel.py:429: size=472 B, count=3, average=157 B
# c:\Users\kriti\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:523: size=472 B, count=2, average=236 B
# c:\Users\kriti\anaconda3\Lib\site-packages\jupyter_client\jsonutil.py:111: size=450 B, count=9, average=50 B
# c:\Users\kriti\anaconda3\Lib\asyncio\windows_events.py:720: size=432 B, count=3, average=144 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:572: size=432 B, count=2, average=216 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:399: size=432 B, count=2, average=216 B
# c:\Users\kriti\anaconda3\Lib\asyncio\events.py:88: size=424 B, count=6, average=71 B
# c:\Users\kriti\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:764: size=424 B, count=2, average=212 B
# C:\Users\kriti\AppData\Local\Temp\ipykernel_5620\2108683704.py:6: size=417 B, count=4, average=104 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:796: size=416 B, count=8, average=52 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:795: size=416 B, count=8, average=52 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:790: size=416 B, count=8, average=52 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:789: size=416 B, count=8, average=52 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:788: size=416 B, count=8, average=52 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:319: size=408 B, count=3, average=136 B
# c:\Users\kriti\anaconda3\Lib\site-packages\stack_data\core.py:104: size=392 B, count=7, average=56 B
# c:\Users\kriti\anaconda3\Lib\site-packages\ipykernel\iostream.py:689: size=384 B, count=4, average=96 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:794: size=384 B, count=4, average=96 B
# c:\Users\kriti\anaconda3\Lib\site-packages\stack_data\utils.py:156: size=376 B, count=3, average=125 B
# c:\Users\kriti\anaconda3\Lib\asyncio\windows_events.py:484: size=368 B, count=2, average=184 B
# c:\Users\kriti\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:427: size=360 B, count=1, average=360 B
# c:\Users\kriti\anaconda3\Lib\site-packages\pygments\regexopt.py:78: size=336 B, count=7, average=48 B
# c:\Users\kriti\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:767: size=336 B, count=1, average=336 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:200: size=332 B, count=1, average=332 B
# c:\Users\kriti\anaconda3\Lib\site-packages\IPython\core\history.py:782: size=332 B, count=1, average=332 B
# c:\Users\kriti\anaconda3\Lib\site-packages\asttokens\line_numbers.py:30: size=315 B, count=6, average=52 B
# c:\Users\kriti\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3130: size=312 B, count=1, average=312 B
# c:\Users\kriti\anaconda3\Lib\site-packages\IPython\core\ultratb.py:1138: size=304 B, count=2, average=152 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:413: size=296 B, count=2, average=148 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:281: size=296 B, count=2, average=148 B
# c:\Users\kriti\anaconda3\Lib\site-packages\asttokens\mark_tokens.py:44: size=296 B, count=2, average=148 B
# c:\Users\kriti\anaconda3\Lib\site-packages\asttokens\asttokens.py:76: size=296 B, count=2, average=148 B
# c:\Users\kriti\anaconda3\Lib\site-packages\asttokens\asttokens.py:56: size=296 B, count=2, average=148 B
# c:\Users\kriti\anaconda3\Lib\site-packages\IPython\core\ultratb.py:1141: size=296 B, count=2, average=148 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:400: size=288 B, count=6, average=48 B
# c:\Users\kriti\anaconda3\Lib\site-packages\tornado\queues.py:248: size=288 B, count=2, average=144 B
# c:\Users\kriti\anaconda3\Lib\asyncio\base_events.py:449: size=288 B, count=2, average=144 B
# c:\Users\kriti\anaconda3\Lib\site-packages\stack_data\core.py:143: size=280 B, count=5, average=56 B
# c:\Users\kriti\anaconda3\Lib\site-packages\tornado\platform\asyncio.py:545: size=272 B, count=6, average=45 B
# c:\Users\kriti\anaconda3\Lib\site-packages\jupyter_client\session.py:278: size=272 B, count=2, average=136 B
# c:\Users\kriti\anaconda3\Lib\site-packages\tornado\platform\asyncio.py:235: size=256 B, count=4, average=64 B
# c:\Users\kriti\anaconda3\Lib\site-packages\asttokens\line_numbers.py:45: size=256 B, count=1, average=256 B
# c:\Users\kriti\anaconda3\Lib\site-packages\ipykernel\iostream.py:120: size=248 B, count=1, average=248 B
# c:\Users\kriti\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3075: size=248 B, count=1, average=248 B
# c:\Users\kriti\anaconda3\Lib\threading.py:348: size=240 B, count=4, average=60 B
# c:\Users\kriti\anaconda3\Lib\logging\__init__.py:1622: size=240 B, count=1, average=240 B
# C:\Users\kriti\AppData\Local\Temp\ipykernel_5620\4255113598.py:4: size=232 B, count=2, average=116 B
# C:\Users\kriti\AppData\Local\Temp\ipykernel_5620\4255113598.py:2: size=232 B, count=2, average=116 B
# c:\Users\kriti\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:534: size=232 B, count=1, average=232 B
# c:\Users\kriti\anaconda3\Lib\site-packages\stack_data\utils.py:34: size=224 B, count=4, average=56 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:805: size=224 B, count=4, average=56 B
# c:\Users\kriti\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3237: size=224 B, count=2, average=112 B
# C:\Users\kriti\AppData\Local\Temp\ipykernel_5620\2108683704.py:13: size=208 B, count=2, average=104 B
# c:\Users\kriti\anaconda3\Lib\site-packages\pygments\style.py:81: size=208 B, count=1, average=208 B
# c:\Users\kriti\anaconda3\Lib\site-packages\jupyter_client\session.py:1085: size=208 B, count=1, average=208 B
# c:\Users\kriti\anaconda3\Lib\site-packages\jupyter_client\session.py:670: size=208 B, count=1, average=208 B
# c:\Users\kriti\anaconda3\Lib\site-packages\jupyter_client\jsonutil.py:75: size=208 B, count=1, average=208 B
# c:\Users\kriti\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:759: size=208 B, count=1, average=208 B
# c:\Users\kriti\anaconda3\Lib\site-packages\ipykernel\ipkernel.py:460: size=208 B, count=1, average=208 B
# c:\Users\kriti\anaconda3\Lib\asyncio\futures.py:422: size=200 B, count=5, average=40 B
# c:\Users\kriti\anaconda3\Lib\site-packages\jupyter_client\session.py:688: size=194 B, count=2, average=97 B
# c:\Users\kriti\anaconda3\Lib\site-packages\stack_data\utils.py:145: size=192 B, count=3, average=64 B
# c:\Users\kriti\anaconda3\Lib\asyncio\windows_events.py:59: size=192 B, count=3, average=64 B
# c:\Users\kriti\anaconda3\Lib\asyncio\proactor_events.py:818: size=192 B, count=3, average=64 B
# c:\Users\kriti\anaconda3\Lib\site-packages\stack_data\core.py:584: size=192 B, count=2, average=96 B
# c:\Users\kriti\anaconda3\Lib\site-packages\jupyter_client\session.py:750: size=192 B, count=2, average=96 B
# c:\Users\kriti\anaconda3\Lib\site-packages\IPython\core\async_helpers.py:128: size=192 B, count=1, average=192 B
# c:\Users\kriti\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3509: size=184 B, count=4, average=46 B
# c:\Users\kriti\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3223: size=184 B, count=3, average=61 B
# c:\Users\kriti\anaconda3\Lib\site-packages\zmq\sugar\socket.py:805: size=184 B, count=2, average=92 B
# c:\Users\kriti\anaconda3\Lib\site-packages\stack_data\core.py:90: size=184 B, count=2, average=92 B
# c:\Users\kriti\anaconda3\Lib\site-packages\stack_data\utils.py:155: size=176 B, count=4, average=44 B
# c:\Users\kriti\anaconda3\Lib\site-packages\stack_data\core.py:652: size=176 B, count=4, average=44 B
# c:\Users\kriti\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1171: size=173 B, count=2, average=86 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:787: size=168 B, count=3, average=56 B
# c:\Users\kriti\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:559: size=160 B, count=1, average=160 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:499: size=160 B, count=1, average=160 B
# c:\Users\kriti\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3493: size=160 B, count=1, average=160 B
# c:\Users\kriti\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:2149: size=160 B, count=1, average=160 B
# c:\Users\kriti\anaconda3\Lib\asyncio\futures.py:398: size=160 B, count=1, average=160 B
# c:\Users\kriti\anaconda3\Lib\asyncio\futures.py:391: size=160 B, count=1, average=160 B
# c:\Users\kriti\anaconda3\Lib\asyncio\futures.py:385: size=160 B, count=1, average=160 B
# c:\Users\kriti\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3485: size=144 B, count=4, average=36 B
# c:\Users\kriti\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3500: size=144 B, count=3, average=48 B
# c:\Users\kriti\anaconda3\Lib\re\__init__.py:260: size=144 B, count=3, average=48 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:269: size=144 B, count=1, average=144 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:815: size=128 B, count=4, average=32 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:801: size=128 B, count=4, average=32 B
# c:\Users\kriti\anaconda3\Lib\warnings.py:532: size=128 B, count=2, average=64 B
# c:\Users\kriti\anaconda3\Lib\site-packages\stack_data\core.py:719: size=128 B, count=2, average=64 B
# c:\Users\kriti\anaconda3\Lib\site-packages\pygments\lexer.py:577: size=128 B, count=2, average=64 B
# c:\Users\kriti\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3515: size=128 B, count=2, average=64 B
# c:\Users\kriti\anaconda3\Lib\concurrent\futures\_base.py:330: size=128 B, count=2, average=64 B
# c:\Users\kriti\anaconda3\Lib\site-packages\IPython\core\ultratb.py:1200: size=127 B, count=1, average=127 B
# c:\Users\kriti\anaconda3\Lib\site-packages\IPython\core\ultratb.py:1022: size=127 B, count=1, average=127 B
# c:\Users\kriti\anaconda3\Lib\threading.py:135: size=120 B, count=2, average=60 B
# c:\Users\kriti\anaconda3\Lib\site-packages\tornado\platform\asyncio.py:598: size=120 B, count=2, average=60 B
# c:\Users\kriti\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:310: size=120 B, count=2, average=60 B
# c:\Users\kriti\anaconda3\Lib\site-packages\pygments\formatters\terminal256.py:136: size=120 B, count=1, average=120 B
# c:\Users\kriti\anaconda3\Lib\site-packages\jupyter_client\session.py:672: size=120 B, count=1, average=120 B
# c:\Users\kriti\anaconda3\Lib\inspect.py:266: size=120 B, count=1, average=120 B
# c:\Users\kriti\anaconda3\Lib\asyncio\base_events.py:778: size=120 B, count=1, average=120 B
# c:\Users\kriti\anaconda3\Lib\ast.py:587: size=120 B, count=1, average=120 B
# c:\Users\kriti\anaconda3\Lib\dis.py:477: size=116 B, count=2, average=58 B
# c:\Users\kriti\anaconda3\Lib\site-packages\stack_data\core.py:784: size=112 B, count=2, average=56 B
# c:\Users\kriti\anaconda3\Lib\site-packages\stack_data\core.py:777: size=112 B, count=2, average=56 B
# c:\Users\kriti\anaconda3\Lib\site-packages\stack_data\core.py:583: size=112 B, count=2, average=56 B
# c:\Users\kriti\anaconda3\Lib\site-packages\stack_data\core.py:152: size=112 B, count=2, average=56 B
# c:\Users\kriti\anaconda3\Lib\site-packages\jupyter_client\session.py:738: size=112 B, count=2, average=56 B
# c:\Users\kriti\anaconda3\Lib\json\encoder.py:249: size=112 B, count=1, average=112 B
# c:\Users\kriti\anaconda3\Lib\site-packages\jupyter_client\session.py:989: size=111 B, count=2, average=56 B
# c:\Users\kriti\anaconda3\Lib\inspect.py:2125: size=104 B, count=1, average=104 B
# c:\Users\kriti\anaconda3\Lib\site-packages\ipykernel\compiler.py:91: size=103 B, count=1, average=103 B
# c:\Users\kriti\anaconda3\Lib\site-packages\zmq\sugar\socket.py:750: size=96 B, count=2, average=48 B
# c:\Users\kriti\anaconda3\Lib\site-packages\jupyter_client\session.py:200: size=96 B, count=2, average=48 B
# c:\Users\kriti\anaconda3\Lib\site-packages\IPython\core\history.py:793: size=96 B, count=2, average=48 B
# c:\Users\kriti\anaconda3\Lib\inspect.py:2134: size=96 B, count=1, average=96 B
# c:\Users\kriti\anaconda3\Lib\site-packages\IPython\core\ultratb.py:1047: size=95 B, count=1, average=95 B
# c:\Users\kriti\anaconda3\Lib\site-packages\pygments\style.py:74: size=94 B, count=2, average=47 B
# c:\Users\kriti\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3224: size=88 B, count=2, average=44 B
# <frozen ntpath>:738: size=84 B, count=1, average=84 B
# <frozen ntpath>:66: size=84 B, count=1, average=84 B
# c:\Users\kriti\anaconda3\Lib\site-packages\jupyter_client\session.py:604: size=83 B, count=1, average=83 B
# c:\Users\kriti\anaconda3\Lib\site-packages\stack_data\core.py:780: size=80 B, count=2, average=40 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:715: size=80 B, count=2, average=40 B
# c:\Users\kriti\anaconda3\Lib\site-packages\pygments\style.py:90: size=80 B, count=1, average=80 B
# c:\Users\kriti\anaconda3\Lib\warnings.py:516: size=72 B, count=1, average=72 B
# c:\Users\kriti\anaconda3\Lib\tracemalloc.py:551: size=72 B, count=1, average=72 B
# c:\Users\kriti\anaconda3\Lib\threading.py:292: size=72 B, count=1, average=72 B
# c:\Users\kriti\anaconda3\Lib\threading.py:290: size=72 B, count=1, average=72 B
# c:\Users\kriti\anaconda3\Lib\threading.py:288: size=72 B, count=1, average=72 B
# c:\Users\kriti\anaconda3\Lib\threading.py:283: size=72 B, count=1, average=72 B
# c:\Users\kriti\anaconda3\Lib\threading.py:282: size=72 B, count=1, average=72 B
# c:\Users\kriti\anaconda3\Lib\site-packages\stack_data\utils.py:15: size=72 B, count=1, average=72 B
# c:\Users\kriti\anaconda3\Lib\site-packages\pygments\lexer.py:369: size=72 B, count=1, average=72 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:1031: size=72 B, count=1, average=72 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:1027: size=72 B, count=1, average=72 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:1013: size=72 B, count=1, average=72 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:887: size=72 B, count=1, average=72 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:861: size=72 B, count=1, average=72 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:843: size=72 B, count=1, average=72 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:800: size=72 B, count=1, average=72 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:786: size=72 B, count=1, average=72 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:781: size=72 B, count=1, average=72 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:702: size=72 B, count=1, average=72 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:700: size=72 B, count=1, average=72 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:689: size=72 B, count=1, average=72 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:682: size=72 B, count=1, average=72 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:674: size=72 B, count=1, average=72 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:618: size=72 B, count=1, average=72 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:544: size=72 B, count=1, average=72 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:223: size=72 B, count=1, average=72 B
# c:\Users\kriti\anaconda3\Lib\linecache.py:52: size=72 B, count=1, average=72 B
# c:\Users\kriti\anaconda3\Lib\inspect.py:1484: size=72 B, count=1, average=72 B
# c:\Users\kriti\anaconda3\Lib\ast.py:574: size=72 B, count=1, average=72 B
# c:\Users\kriti\anaconda3\Lib\ast.py:537: size=72 B, count=1, average=72 B
# c:\Users\kriti\anaconda3\Lib\ast.py:199: size=72 B, count=1, average=72 B
# C:\Users\kriti\AppData\Local\Temp\ipykernel_5620\4255113598.py:0: size=72 B, count=1, average=72 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:565: size=64 B, count=2, average=32 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:313: size=64 B, count=2, average=32 B
# c:\Users\kriti\anaconda3\Lib\asyncio\base_events.py:1970: size=64 B, count=2, average=32 B
# c:\Users\kriti\anaconda3\Lib\threading.py:652: size=64 B, count=1, average=64 B
# c:\Users\kriti\anaconda3\Lib\site-packages\zmq\sugar\socket.py:809: size=64 B, count=1, average=64 B
# c:\Users\kriti\anaconda3\Lib\site-packages\tornado\platform\asyncio.py:550: size=64 B, count=1, average=64 B
# c:\Users\kriti\anaconda3\Lib\site-packages\jupyter_client\session.py:1053: size=64 B, count=1, average=64 B
# c:\Users\kriti\anaconda3\Lib\site-packages\jupyter_client\session.py:663: size=64 B, count=1, average=64 B
# c:\Users\kriti\anaconda3\Lib\site-packages\jupyter_client\jsonutil.py:73: size=64 B, count=1, average=64 B
# c:\Users\kriti\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:750: size=64 B, count=1, average=64 B
# c:\Users\kriti\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:710: size=64 B, count=1, average=64 B
# c:\Users\kriti\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:68: size=64 B, count=1, average=64 B
# c:\Users\kriti\anaconda3\Lib\site-packages\ipykernel\ipkernel.py:456: size=64 B, count=1, average=64 B
# c:\Users\kriti\anaconda3\Lib\site-packages\ipykernel\ipkernel.py:364: size=64 B, count=1, average=64 B
# c:\Users\kriti\anaconda3\Lib\site-packages\ipykernel\ipkernel.py:363: size=64 B, count=1, average=64 B
# c:\Users\kriti\anaconda3\Lib\site-packages\ipykernel\ipkernel.py:361: size=64 B, count=1, average=64 B
# c:\Users\kriti\anaconda3\Lib\site-packages\ipykernel\ipkernel.py:280: size=64 B, count=1, average=64 B
# c:\Users\kriti\anaconda3\Lib\site-packages\ipykernel\ipkernel.py:277: size=64 B, count=1, average=64 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:490: size=64 B, count=1, average=64 B
# c:\Users\kriti\anaconda3\Lib\site-packages\asttokens\util.py:258: size=64 B, count=1, average=64 B
# c:\Users\kriti\anaconda3\Lib\site-packages\IPython\core\ultratb.py:1228: size=64 B, count=1, average=64 B
# c:\Users\kriti\anaconda3\Lib\site-packages\IPython\core\ultratb.py:1097: size=64 B, count=1, average=64 B
# c:\Users\kriti\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3566: size=64 B, count=1, average=64 B
# c:\Users\kriti\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3303: size=64 B, count=1, average=64 B
# c:\Users\kriti\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3300: size=64 B, count=1, average=64 B
# c:\Users\kriti\anaconda3\Lib\tracemalloc.py:558: size=56 B, count=1, average=56 B
# c:\Users\kriti\anaconda3\Lib\site-packages\tornado\platform\asyncio.py:575: size=56 B, count=1, average=56 B
# c:\Users\kriti\anaconda3\Lib\site-packages\stack_data\core.py:702: size=56 B, count=1, average=56 B
# c:\Users\kriti\anaconda3\Lib\site-packages\pygments\regexopt.py:66: size=56 B, count=1, average=56 B
# c:\Users\kriti\anaconda3\Lib\site-packages\pygments\regexopt.py:39: size=56 B, count=1, average=56 B
# c:\Users\kriti\anaconda3\Lib\site-packages\pygments\formatters\terminal256.py:138: size=56 B, count=1, average=56 B
# c:\Users\kriti\anaconda3\Lib\site-packages\jupyter_client\session.py:1088: size=56 B, count=1, average=56 B
# c:\Users\kriti\anaconda3\Lib\site-packages\executing\executing.py:636: size=56 B, count=1, average=56 B
# c:\Users\kriti\anaconda3\Lib\site-packages\IPython\core\ultratb.py:1201: size=56 B, count=1, average=56 B
# c:\Users\kriti\anaconda3\Lib\site-packages\IPython\core\payload.py:54: size=56 B, count=1, average=56 B
# c:\Users\kriti\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3503: size=56 B, count=1, average=56 B
# c:\Users\kriti\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3498: size=56 B, count=1, average=56 B
# c:\Users\kriti\anaconda3\Lib\dis.py:653: size=56 B, count=1, average=56 B
# c:\Users\kriti\anaconda3\Lib\concurrent\futures\_base.py:334: size=56 B, count=1, average=56 B
# c:\Users\kriti\anaconda3\Lib\asyncio\windows_events.py:447: size=56 B, count=1, average=56 B
# c:\Users\kriti\anaconda3\Lib\asyncio\base_events.py:761: size=56 B, count=1, average=56 B
# c:\Users\kriti\anaconda3\Lib\site-packages\ipykernel\ipkernel.py:450: size=50 B, count=1, average=50 B
# c:\Users\kriti\anaconda3\Lib\ast.py:428: size=50 B, count=1, average=50 B
# c:\Users\kriti\anaconda3\Lib\site-packages\zmq\eventloop\zmqstream.py:663: size=48 B, count=1, average=48 B
# c:\Users\kriti\anaconda3\Lib\site-packages\zmq\eventloop\zmqstream.py:584: size=48 B, count=1, average=48 B
# c:\Users\kriti\anaconda3\Lib\site-packages\tornado\platform\asyncio.py:615: size=48 B, count=1, average=48 B
# c:\Users\kriti\anaconda3\Lib\site-packages\tornado\concurrent.py:193: size=48 B, count=1, average=48 B
# c:\Users\kriti\anaconda3\Lib\site-packages\stack_data\core.py:81: size=48 B, count=1, average=48 B
# c:\Users\kriti\anaconda3\Lib\site-packages\dateutil\parser\_parser.py:1195: size=48 B, count=1, average=48 B
# c:\Users\kriti\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3505: size=48 B, count=1, average=48 B
# c:\Users\kriti\anaconda3\Lib\site-packages\IPython\core\history.py:805: size=45 B, count=1, average=45 B
# c:\Users\kriti\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3599: size=40 B, count=1, average=40 B
# c:\Users\kriti\anaconda3\Lib\asyncio\windows_events.py:462: size=34 B, count=1, average=34 B
# c:\Users\kriti\anaconda3\Lib\site-packages\jupyter_client\session.py:996: size=32 B, count=1, average=32 B
# c:\Users\kriti\anaconda3\Lib\site-packages\jupyter_client\session.py:603: size=32 B, count=1, average=32 B
# c:\Users\kriti\anaconda3\Lib\site-packages\ipykernel\iostream.py:167: size=32 B, count=1, average=32 B
# c:\Users\kriti\anaconda3\Lib\site-packages\IPython\core\compilerop.py:192: size=32 B, count=1, average=32 B
# c:\Users\kriti\anaconda3\Lib\concurrent\futures\_base.py:421: size=32 B, count=1, average=32 B
# c:\Users\kriti\anaconda3\Lib\asyncio\base_events.py:781: size=32 B, count=1, average=32 B
# c:\Users\kriti\anaconda3\Lib\threading.py:351: size=28 B, count=1, average=28 B
# c:\Users\kriti\anaconda3\Lib\site-packages\asttokens\line_numbers.py:32: size=28 B, count=1, average=28 B
# c:\Users\kriti\anaconda3\Lib\site-packages\IPython\core\compilerop.py:172: size=28 B, count=1, average=28 B
